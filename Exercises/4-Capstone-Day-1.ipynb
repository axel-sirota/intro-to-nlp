# %%
import pandas as pd

# %%
# %%writefile get_capstone_data.sh
# if [ ! -f twcs.csv ]; then
#   wget -O twcs.csv https://www.dropbox.com/scl/fi/6w2dchvsthwdol934nprt/twcs.csv?rlkey=u5205iehhrog88qt8iwm4udxs&dl=0
# fi
# Out:
# Writing get_capstone_data.sh

# %%
# !bash get_capstone_data.sh
# Out:
# --2023-09-07 20:54:47--  https://www.dropbox.com/scl/fi/6w2dchvsthwdol934nprt/twcs.csv?rlkey=u5205iehhrog88qt8iwm4udxs
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/e/scl/fi/6w2dchvsthwdol934nprt/twcs.csv?rlkey=u5205iehhrog88qt8iwm4udxs [following]
# --2023-09-07 20:54:47--  https://www.dropbox.com/e/scl/fi/6w2dchvsthwdol934nprt/twcs.csv?rlkey=u5205iehhrog88qt8iwm4udxs
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc44d339add9c346560bc1cfc6ba.dl.dropboxusercontent.com/cd/0/inline/CDTCtElV0L0tLs34xDs_LwFy3unqCaT-F7m5GqczTYS2eGFVqUpF1L6Ev5XUqldmmqXzphE7Ner5GYHadD58xUF94aMtdS60cgcheIXDrac0CCd7JNuPJn2I2gWMDf9bAczq8g7MzNk0fsbO6Lvm4ye6/file# [following]
# --2023-09-07 20:54:48--  https://uc44d339add9c346560bc1cfc6ba.dl.dropboxusercontent.com/cd/0/inline/CDTCtElV0L0tLs34xDs_LwFy3unqCaT-F7m5GqczTYS2eGFVqUpF1L6Ev5XUqldmmqXzphE7Ner5GYHadD58xUF94aMtdS60cgcheIXDrac0CCd7JNuPJn2I2gWMDf9bAczq8g7MzNk0fsbO6Lvm4ye6/file
# Resolving uc44d339add9c346560bc1cfc6ba.dl.dropboxusercontent.com (uc44d339add9c346560bc1cfc6ba.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6018:15::a27d:30f
# Connecting to uc44d339add9c346560bc1cfc6ba.dl.dropboxusercontent.com (uc44d339add9c346560bc1cfc6ba.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 516508641 (493M) [text/plain]
# Saving to: ‘twcs.csv’
#
# twcs.csv            100%[===================>] 492.58M  76.3MB/s    in 8.8s
#
# 2023-09-07 20:54:57 (55.7 MB/s) - ‘twcs.csv’ saved [516508641/516508641]

# %%
twitter = pd.read_csv('./twcs.csv')

# %%
twitter
# Out:
#          tweet_id   author_id  inbound                      created_at  \
# 0               1  sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
# 1               2      115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2               3      115712     True  Tue Oct 31 22:08:27 +0000 2017
# 3               4  sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 4               5      115712     True  Tue Oct 31 21:49:35 +0000 2017
# ...           ...         ...      ...                             ...
# 2811769   2987947  sprintcare    False  Wed Nov 22 08:43:51 +0000 2017
# 2811770   2987948      823869     True  Wed Nov 22 08:35:16 +0000 2017
# 2811771   2812240      121673     True  Thu Nov 23 04:13:07 +0000 2017
# 2811772   2987949      AldiUK    False  Wed Nov 22 08:31:24 +0000 2017
# 2811773   2987950      823870     True  Tue Nov 21 22:01:04 +0000 2017
#
#                                                       text response_tweet_id  \
# 0        @115712 I understand. I would like to assist y...                 2
# 1            @sprintcare and how do you propose we do that               NaN
# 2        @sprintcare I have sent several private messag...                 1
# 3        @115712 Please send us a Private Message so th...                 3
# 4                                       @sprintcare I did.                 4
# ...                                                    ...               ...
# 2811769  @823869 Hey, we'd be happy to look into this f...               NaN
# 2811770  @115714 wtf!? I’ve been having really shitty s...           2987947
# 2811771  @143549 @sprintcare You have to go to https://...               NaN
# 2811772  @823870 Sounds delicious, Sarah! 😋 https://t.c...               NaN
# 2811773  @AldiUK  warm sloe gin mince pies with ice cre...   2987951,2987949
#
#          in_response_to_tweet_id
# 0                            3.0
# 1                            1.0
# 2                            4.0
# 3                            5.0
# 4                            6.0
# ...                          ...
# 2811769                2987948.0
# 2811770                      NaN
# 2811771                2812239.0
# 2811772                2987950.0
# 2811773                      NaN
#
# [2811774 rows x 7 columns]
